# %% [markdown]
# #### 安装Anaconda/Miniconda
# * 下载Anaconda安装程序（Anaconda for Windows and Mac/ Miniconda for Linux）：[Anaconda/Miniconda](https://www.anaconda.com/download/success)
# * 安装Anaconda
# * 将Anaconda安装路径的condalib添加到环境变量PATH中（Windows）或将其添加到bashrc中（Mac and Linux）
# * 启动控制台，创建虚拟环境 conda create -n rl python==3.8
# * 关闭控制台后启动新的控制台，激活环境 conda activate rl

# %% [markdown]
# #### 安装Gymnasium
# * 进入rl虚拟环境后，通过pip安装gymnasium

# %%
! pip install "gymnasium"
! pip install "gymnasium[atari, accept-rom-license]"
! pip install matplotlib
! pip install numpy
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: gymnasium in /usr/local/Caskroom/miniconda/base/envs/smac/lib/python3.11/site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/Caskroom/miniconda/base/envs/smac/lib/python3.11/site-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/Caskroom/miniconda/base/envs/smac/lib/python3.11/site-packages (from gymnasium) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/Caskroom/miniconda/base/envs/smac/lib/python3.11/site-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/Caskroom/miniconda/base/envs/smac/lib/python3.11/site-packages (from gymnasium) (0.0.4)
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: gymnasium[accept-rom-license,atari] in /usr/local/Caskroom/miniconda/base/envs/smac/lib/python3.11/site-packages (1.1.1)
# WARNING: gymnasium 1.1.1 does not provide the extra 'accept-rom-license'
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/Caskroom/miniconda/base/envs/smac/lib/python3.11/site-packages (from gymnasium[accept-rom-license,atari]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/Caskroom/miniconda/base/envs/smac/lib/python3.11/site-packages (from gymnasium[accept-rom-license,atari]) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/Caskroom/miniconda/base/envs/smac/lib/python3.11/site-packages (from gymnasium[accept-rom-license,atari]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/Caskroom/miniconda/base/envs/smac/lib/python3.11/site-packages (from gymnasium[accept-rom-license,atari]) (0.0.4)
# Requirement already satisfied: ale_py>=0.9 in /usr/local/Caskroom/miniconda/base/envs/smac/lib/python3.11/site-packages (from gymnasium[accept-rom-license,atari]) (0.11.1)
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: matplotlib in /usr/local/Caskroom/miniconda/base/envs/smac/lib/python3.11/site-packages (3.9.1.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/Caskroom/miniconda/base/envs/smac/lib/python3.11/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/Caskroom/miniconda/base/envs/smac/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/Caskroom/miniconda/base/envs/smac/lib/python3.11/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/Caskroom/miniconda/base/envs/smac/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in /usr/local/Caskroom/miniconda/base/envs/smac/lib/python3.11/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/Caskroom/miniconda/base/envs/smac/lib/python3.11/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /usr/local/Caskroom/miniconda/base/envs/smac/lib/python3.11/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/Caskroom/miniconda/base/envs/smac/lib/python3.11/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/Caskroom/miniconda/base/envs/smac/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/Caskroom/miniconda/base/envs/smac/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: numpy in /usr/local/Caskroom/miniconda/base/envs/smac/lib/python3.11/site-packages (1.26.4)

# %% [markdown]
# #### 测试Gym安装结果

# %%
# 引入gym包
import gymnasium as gym
# 初始化强化学习环境
env = gym.make('Acrobot-v1', render_mode='human')

# %% [markdown]
# gymnasium和gym包采用相似的API接口封装，为了兼容旧版gym环境，在包引入的时候将gymnasium包冲命名为gym
#
# gym.make中的CartPole-v1是gym中的一个基础环境，具体支持的训练环境可参考：[gymnasium document](https://gymnasium.farama.org/)
#
# render_mode可选human或rgb_array

# %%
observation, info = env.reset(seed=1)
print(observation)
print(info)
env.close()
# Out:
# [ 0.00118216  0.04504637 -0.03558404  0.04486495]
# {}

# %% [markdown]
# 此时屏幕中应该弹出一个CartPole环境的倒立摆环境，打印出的observation代表了此刻倒立摆的状态，具体的四个变量分别代表：[CartPole]（https://gymnasium.farama.org/environments/classic_control/cart_pole/）
#
# reset表示环境重置或初始化，返回observation和环境信息。
#
# 虽然状态可以通过查询文档获知，但是一般下我们可以假设状态的内容是不可知的。
#
# 现在通过env.close关闭环境，注意这个命令在jupyter notebook中不起作用，但是在python文件中可以。

# %%
import gymnasium as gym

# 引入gym包
env = gym.make("Acrobot-v1", render_mode="rgb_array")

#重置环境，返回观测和信息
observation, info = env.reset(seed=233)
episode_return = 0
return_list = []
for _ in range(10000):
    # 从行为空间中随机选择一个行为
    action = env.action_space.sample()

    # step函数表示应用该行为进行一步的推演；
    # 返回观测，刚刚行为的奖励，推演是否结束，该回合是否阶段，其他信息
    observation, reward, terminated, truncated, info = env.step(action)
    episode_return += reward

    # 如果回合结束或回合裁剪，重新启动一个环境。
    if terminated or truncated:
        observation, info = env.reset()
        return_list.append(episode_return)
        episode_return = 0
env.close()

# %% [markdown]
# 当render_mode为rgb_array时，不弹出动画，此时的行为是随机行为。
#
# 我们可以采用matplotlib画出10000步内奖励的图

# %%
import matplotlib.pyplot as plt
episodes_list = list(range(len(return_list)))
plt.plot(episodes_list, return_list)
plt.xlabel('Episodes')
plt.ylabel('Returns')
plt.title('Random Walk on {}'.format('CartPole-v1'))
plt.show()

# %% [markdown]
# #### 实验1练习
#
# 实现爬山算法完成CartPole-v1任务
#
# 爬山算法：在当前最优的策略参数基础上随机探索

# %%
# 引入对应的包和实验环境
import gymnasium as gym
import numpy as np
from collections import deque

import time


env = gym.make('Acrobot-v1', render_mode="rgb_array")
print('observation space:', env.observation_space)
print('action space:', env.action_space)
threshold = env.spec.reward_threshold
print('threshold: ', threshold)
# Out:
# observation space: Box([ -1.        -1.        -1.        -1.       -12.566371 -28.274334], [ 1.        1.        1.        1.       12.566371 28.274334], (6,), float32)
# action space: Discrete(3)
# threshold:  -100.0

# %% [markdown]
# ##### 定义policy
# 1. policy中维持一组维度为（state_space, action_space）的weight变量；
# 2. 在forward计算中计算weight * state，获得维度为action_space的结果；
# 3. 在forward的返回值中归一化计算选择每个action的概率：$\frac{e^{p_i}}{\sum_0^a{e^{p_i}}}$；
# 4. 在act中选择概率最大的行为。

# %%
class Policy():
    def __init__(self, s_size=4, a_size=2):
        self.w = 1e-4*np.random.rand(s_size, a_size)  # weights for simple linear policy: state_space x action_space
        
    def forward(self, state):
        x = np.dot(state, self.w)
        return np.exp(x)/sum(np.exp(x))
    
    def act(self, state):
        probs = self.forward(state)
        action = np.argmax(probs)          
        return action

policy = Policy(6, 3)

# %% [markdown]
# ##### 定义hill climbing函数
#
# 1. 维护一组最佳weight和最好结果
# 2. 在最佳weight上增加一定的噪声用来探索
# 3. 在增加噪声后的weight的基础上跑CartPole环境
# 4. 如果环境跑分比当前最好的结果好：则记录最佳评分和最佳weight，同时减半噪声范围，计算新的weight进行探索
# 5. 如果环境跑分比当前最好的结果差：则翻倍噪声范围，计算新的weight进行探索

# %%
def hill_climbing(n_episodes=10000, gamma=0.99, noise_scale=1e-2):

    scores_deque = deque(maxlen=100)
    best_Gt = -np.Inf
    best_w = policy.w

    for i_episode in range(1, n_episodes+1):
        rewards = []
        state, info = env.reset()
        timesteps = 0 
        
        while True:
            action = policy.act(state)
            state, reward, done, truncated, _ = env.step(action)            
            rewards.append(reward)
            timesteps += 1  
            if done or truncated:
                break 
        
        # 计算单局的收益，并加入到scores_deque中
        # TODO

        discounts = [gamma ** i for i in range(len(rewards)+ 1)]
        total_reward = sum([a * b for a, b in zip(discounts, rewards)])
        #total_reward = sum(rewards)
        scores_deque.append(total_reward)

        if total_reward >= best_Gt: 
            # 更新最大收益
            # 更新最佳权重
            # 调整噪声范围，减半噪声范围，但不能小于1e-3
            # TODO
            best_Gt = total_reward
            best_w = policy.w
            noise_scale = max(1e-3, noise_scale / 2)
            
            print('Ep.: {:3d} , timesteps: {:3d}, noise_scale (Gt >= best(Gt)): {:.4f}, Gt {:.4f}, \tAvg.Score:  {:.3f}'\
                  .format(i_episode, timesteps, noise_scale, total_reward, np.mean(scores_deque)))
            # 更新policy的权重
            # TODO
            policy.w += noise_scale * np.random.rand(*policy.w.shape)
        else: 
            noise_scale = min(2, noise_scale * 2)
            # 增大噪声范围，倍增噪声范围，最大不超过2
            print('Ep.: {:3d} , timesteps: {:3d}, noise_scale (Gt < best(Gt)): {:.4f}, Gt {:.4f}, \tAvg.Score:  {:.3f}'\
                  .format(i_episode, timesteps, noise_scale, total_reward, np.mean(scores_deque)))
            # 基于当前最优权重，更新policy的权重
            policy.w = best_w + noise_scale * np.random.rand(*policy.w.shape) 

        
        if np.mean(scores_deque)>=threshold:
            print('Environment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)))
            policy.w = best_w
            break
    
    return

# %%
# 测试
hill_climbing()

for i in range(10):
    env = gym.make('Acrobot-v1', render_mode="human")
    state, info=env.reset()
    while True:
        action = policy.act(state)
        state, reward, done, trancate, _ = env.step(action)   
        if done or trancate:
            break
# Out:
# Ep.:   1 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0050, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:   2 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0025, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:   3 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0013, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:   4 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:   5 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:   6 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:   7 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:   8 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:   9 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  10 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  11 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  12 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  13 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  14 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  15 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  16 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  17 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  18 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  19 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  20 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  21 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  22 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  23 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  24 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  25 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  26 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  27 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  28 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  29 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  30 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  31 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  32 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  33 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  34 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  35 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  36 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  37 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  38 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  39 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  40 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  41 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  42 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  43 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  44 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  45 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  46 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  47 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  48 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  49 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  50 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  51 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  52 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  53 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  54 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  55 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  56 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  57 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  58 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  59 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  60 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  61 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  62 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  63 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  64 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  65 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  66 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  67 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  68 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  69 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  70 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  71 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  72 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  73 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  74 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  75 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  76 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  77 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  78 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  79 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  80 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  81 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  82 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  83 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  84 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  85 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  86 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  87 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  88 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  89 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  90 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  91 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  92 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  93 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  94 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  95 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  96 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  97 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  98 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.:  99 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.: 100 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.: 101 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.: 102 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.: 103 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.: 104 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.: 105 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.: 106 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.: 107 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.: 108 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.: 109 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.: 110 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.: 111 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.: 112 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.: 113 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.: 114 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.: 115 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3430, 	Avg.Score:  -500.000
# Ep.: 116 , timesteps: 497, noise_scale (Gt >= best(Gt)): 0.0010, Gt -99.3160, 	Avg.Score:  -499.960
# Ep.: 117 , timesteps: 500, noise_scale (Gt < best(Gt)): 0.0020, Gt -99.3430, 	Avg.Score:  -499.960
# Ep.: 118 , timesteps: 192, noise_scale (Gt >= best(Gt)): 0.0010, Gt -85.3336, 	Avg.Score:  -496.870
# Ep.: 119 , timesteps: 249, noise_scale (Gt < best(Gt)): 0.0020, Gt -91.7296, 	Avg.Score:  -494.350
# Ep.: 120 , timesteps: 500, noise_scale (Gt < best(Gt)): 0.0040, Gt -99.3430, 	Avg.Score:  -494.350
# Ep.: 121 , timesteps: 500, noise_scale (Gt < best(Gt)): 0.0080, Gt -99.3430, 	Avg.Score:  -494.350
# Ep.: 122 , timesteps: 500, noise_scale (Gt < best(Gt)): 0.0160, Gt -99.3430, 	Avg.Score:  -494.350
# Ep.: 123 , timesteps: 500, noise_scale (Gt < best(Gt)): 0.0320, Gt -99.3430, 	Avg.Score:  -494.350
# Ep.: 124 , timesteps: 500, noise_scale (Gt < best(Gt)): 0.0640, Gt -99.3430, 	Avg.Score:  -494.350
# Ep.: 125 , timesteps: 500, noise_scale (Gt < best(Gt)): 0.1280, Gt -99.3430, 	Avg.Score:  -494.350
# Ep.: 126 , timesteps: 500, noise_scale (Gt < best(Gt)): 0.2560, Gt -99.3430, 	Avg.Score:  -494.350
# Ep.: 127 , timesteps: 500, noise_scale (Gt < best(Gt)): 0.5120, Gt -99.3430, 	Avg.Score:  -494.350
# Ep.: 128 , timesteps: 100, noise_scale (Gt >= best(Gt)): 0.2560, Gt -63.0270, 	Avg.Score:  -490.340
# Ep.: 129 , timesteps: 500, noise_scale (Gt < best(Gt)): 0.5120, Gt -99.3430, 	Avg.Score:  -490.340
# Ep.: 130 , timesteps: 500, noise_scale (Gt < best(Gt)): 1.0240, Gt -99.3430, 	Avg.Score:  -490.340
# Ep.: 131 , timesteps: 173, noise_scale (Gt < best(Gt)): 2.0000, Gt -82.2477, 	Avg.Score:  -487.060
# Ep.: 132 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -487.060
# Ep.: 133 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -487.060
# Ep.: 134 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -487.060
# Ep.: 135 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -487.060
# Ep.: 136 , timesteps: 200, noise_scale (Gt < best(Gt)): 2.0000, Gt -86.4667, 	Avg.Score:  -484.050
# Ep.: 137 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -484.050
# Ep.: 138 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -484.050
# Ep.: 139 , timesteps: 224, noise_scale (Gt < best(Gt)): 2.0000, Gt -89.3672, 	Avg.Score:  -481.280
# Ep.: 140 , timesteps:  88, noise_scale (Gt >= best(Gt)): 1.0000, Gt -58.2879, 	Avg.Score:  -477.150
# Ep.: 141 , timesteps:  81, noise_scale (Gt >= best(Gt)): 0.5000, Gt -55.2477, 	Avg.Score:  -472.950
# Ep.: 142 , timesteps:  83, noise_scale (Gt < best(Gt)): 1.0000, Gt -56.1382, 	Avg.Score:  -468.770
# Ep.: 143 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -468.770
# Ep.: 144 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -468.770
# Ep.: 145 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -468.770
# Ep.: 146 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -468.770
# Ep.: 147 , timesteps:  85, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.0111, 	Avg.Score:  -464.610
# Ep.: 148 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -464.610
# Ep.: 149 , timesteps:  98, noise_scale (Gt < best(Gt)): 2.0000, Gt -62.2763, 	Avg.Score:  -460.580
# Ep.: 150 , timesteps: 113, noise_scale (Gt < best(Gt)): 2.0000, Gt -67.5554, 	Avg.Score:  -456.700
# Ep.: 151 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -456.700
# Ep.: 152 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -456.700
# Ep.: 153 , timesteps: 102, noise_scale (Gt < best(Gt)): 2.0000, Gt -63.7628, 	Avg.Score:  -452.710
# Ep.: 154 , timesteps: 135, noise_scale (Gt < best(Gt)): 2.0000, Gt -73.9915, 	Avg.Score:  -449.050
# Ep.: 155 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -449.050
# Ep.: 156 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -449.050
# Ep.: 157 , timesteps:  87, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.8666, 	Avg.Score:  -444.910
# Ep.: 158 , timesteps:  86, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.4410, 	Avg.Score:  -440.760
# Ep.: 159 , timesteps:  85, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.0111, 	Avg.Score:  -436.600
# Ep.: 160 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -436.600
# Ep.: 161 , timesteps:  95, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.1216, 	Avg.Score:  -432.540
# Ep.: 162 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -432.540
# Ep.: 163 , timesteps: 103, noise_scale (Gt < best(Gt)): 2.0000, Gt -64.1252, 	Avg.Score:  -428.560
# Ep.: 164 , timesteps: 117, noise_scale (Gt < best(Gt)): 2.0000, Gt -68.8339, 	Avg.Score:  -424.720
# Ep.: 165 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -424.720
# Ep.: 166 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -424.720
# Ep.: 167 , timesteps:  95, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.1216, 	Avg.Score:  -420.660
# Ep.: 168 , timesteps: 101, noise_scale (Gt < best(Gt)): 2.0000, Gt -63.3968, 	Avg.Score:  -416.660
# Ep.: 169 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -416.660
# Ep.: 170 , timesteps:  98, noise_scale (Gt < best(Gt)): 2.0000, Gt -62.2763, 	Avg.Score:  -412.630
# Ep.: 171 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -412.630
# Ep.: 172 , timesteps: 108, noise_scale (Gt < best(Gt)): 2.0000, Gt -65.8834, 	Avg.Score:  -408.700
# Ep.: 173 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -408.700
# Ep.: 174 , timesteps: 122, noise_scale (Gt < best(Gt)): 2.0000, Gt -70.3613, 	Avg.Score:  -404.910
# Ep.: 175 , timesteps:  67, noise_scale (Gt >= best(Gt)): 1.0000, Gt -48.4863, 	Avg.Score:  -400.570
# Ep.: 176 , timesteps:  89, noise_scale (Gt < best(Gt)): 2.0000, Gt -58.7050, 	Avg.Score:  -396.450
# Ep.: 177 , timesteps:  90, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.1180, 	Avg.Score:  -392.340
# Ep.: 178 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -392.340
# Ep.: 179 , timesteps:  82, noise_scale (Gt < best(Gt)): 2.0000, Gt -55.6952, 	Avg.Score:  -388.150
# Ep.: 180 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -388.150
# Ep.: 181 , timesteps: 122, noise_scale (Gt < best(Gt)): 2.0000, Gt -70.3613, 	Avg.Score:  -384.360
# Ep.: 182 , timesteps: 177, noise_scale (Gt < best(Gt)): 2.0000, Gt -82.9473, 	Avg.Score:  -381.120
# Ep.: 183 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -381.120
# Ep.: 184 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -381.120
# Ep.: 185 , timesteps:  94, noise_scale (Gt < best(Gt)): 2.0000, Gt -60.7289, 	Avg.Score:  -377.050
# Ep.: 186 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -377.050
# Ep.: 187 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -377.050
# Ep.: 188 , timesteps: 126, noise_scale (Gt < best(Gt)): 2.0000, Gt -71.5292, 	Avg.Score:  -373.300
# Ep.: 189 , timesteps:  87, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.8666, 	Avg.Score:  -369.160
# Ep.: 190 , timesteps: 101, noise_scale (Gt < best(Gt)): 2.0000, Gt -63.3968, 	Avg.Score:  -365.160
# Ep.: 191 , timesteps:  80, noise_scale (Gt < best(Gt)): 2.0000, Gt -54.7956, 	Avg.Score:  -360.950
# Ep.: 192 , timesteps: 123, noise_scale (Gt < best(Gt)): 2.0000, Gt -70.6577, 	Avg.Score:  -357.170
# Ep.: 193 , timesteps: 114, noise_scale (Gt < best(Gt)): 2.0000, Gt -67.8799, 	Avg.Score:  -353.300
# Ep.: 194 , timesteps: 108, noise_scale (Gt < best(Gt)): 2.0000, Gt -65.8834, 	Avg.Score:  -349.370
# Ep.: 195 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -349.370
# Ep.: 196 , timesteps:  87, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.8666, 	Avg.Score:  -345.230
# Ep.: 197 , timesteps: 101, noise_scale (Gt < best(Gt)): 2.0000, Gt -63.3968, 	Avg.Score:  -341.230
# Ep.: 198 , timesteps:  98, noise_scale (Gt < best(Gt)): 2.0000, Gt -62.2763, 	Avg.Score:  -337.200
# Ep.: 199 , timesteps:  85, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.0111, 	Avg.Score:  -333.040
# Ep.: 200 , timesteps: 130, noise_scale (Gt < best(Gt)): 2.0000, Gt -72.6511, 	Avg.Score:  -329.330
# Ep.: 201 , timesteps:  88, noise_scale (Gt < best(Gt)): 2.0000, Gt -58.2879, 	Avg.Score:  -325.200
# Ep.: 202 , timesteps:  74, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.9859, 	Avg.Score:  -320.930
# Ep.: 203 , timesteps:  91, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.5268, 	Avg.Score:  -316.830
# Ep.: 204 , timesteps: 104, noise_scale (Gt < best(Gt)): 2.0000, Gt -64.4839, 	Avg.Score:  -312.860
# Ep.: 205 , timesteps: 159, noise_scale (Gt < best(Gt)): 2.0000, Gt -79.5657, 	Avg.Score:  -309.440
# Ep.: 206 , timesteps: 176, noise_scale (Gt < best(Gt)): 2.0000, Gt -82.7750, 	Avg.Score:  -306.190
# Ep.: 207 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -306.190
# Ep.: 208 , timesteps: 115, noise_scale (Gt < best(Gt)): 2.0000, Gt -68.2011, 	Avg.Score:  -302.330
# Ep.: 209 , timesteps: 118, noise_scale (Gt < best(Gt)): 2.0000, Gt -69.1456, 	Avg.Score:  -298.500
# Ep.: 210 , timesteps:  87, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.8666, 	Avg.Score:  -294.360
# Ep.: 211 , timesteps:  97, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.8953, 	Avg.Score:  -290.320
# Ep.: 212 , timesteps:  74, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.9859, 	Avg.Score:  -286.050
# Ep.: 213 , timesteps:  73, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.5009, 	Avg.Score:  -281.770
# Ep.: 214 , timesteps:  91, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.5268, 	Avg.Score:  -277.670
# Ep.: 215 , timesteps:  82, noise_scale (Gt < best(Gt)): 2.0000, Gt -55.6952, 	Avg.Score:  -273.480
# Ep.: 216 , timesteps: 184, noise_scale (Gt < best(Gt)): 2.0000, Gt -84.1057, 	Avg.Score:  -270.350
# Ep.: 217 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -270.350
# Ep.: 218 , timesteps:  93, noise_scale (Gt < best(Gt)): 2.0000, Gt -60.3322, 	Avg.Score:  -269.360
# Ep.: 219 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -271.880
# Ep.: 220 , timesteps:  87, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.8666, 	Avg.Score:  -267.740
# Ep.: 221 , timesteps:  80, noise_scale (Gt < best(Gt)): 2.0000, Gt -54.7956, 	Avg.Score:  -263.530
# Ep.: 222 , timesteps:  81, noise_scale (Gt < best(Gt)): 2.0000, Gt -55.2477, 	Avg.Score:  -259.330
# Ep.: 223 , timesteps:  81, noise_scale (Gt < best(Gt)): 2.0000, Gt -55.2477, 	Avg.Score:  -255.130
# Ep.: 224 , timesteps:  72, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.0110, 	Avg.Score:  -250.840
# Ep.: 225 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -250.840
# Ep.: 226 , timesteps: 122, noise_scale (Gt < best(Gt)): 2.0000, Gt -70.3613, 	Avg.Score:  -247.050
# Ep.: 227 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -247.050
# Ep.: 228 , timesteps:  85, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.0111, 	Avg.Score:  -246.900
# Ep.: 229 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -246.900
# Ep.: 230 , timesteps:  94, noise_scale (Gt < best(Gt)): 2.0000, Gt -60.7289, 	Avg.Score:  -242.830
# Ep.: 231 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -246.110
# Ep.: 232 , timesteps: 197, noise_scale (Gt < best(Gt)): 2.0000, Gt -86.0524, 	Avg.Score:  -243.070
# Ep.: 233 , timesteps:  79, noise_scale (Gt < best(Gt)): 2.0000, Gt -54.3390, 	Avg.Score:  -238.850
# Ep.: 234 , timesteps:  79, noise_scale (Gt < best(Gt)): 2.0000, Gt -54.3390, 	Avg.Score:  -234.630
# Ep.: 235 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -234.630
# Ep.: 236 , timesteps: 118, noise_scale (Gt < best(Gt)): 2.0000, Gt -69.1456, 	Avg.Score:  -233.810
# Ep.: 237 , timesteps: 205, noise_scale (Gt < best(Gt)): 2.0000, Gt -87.1300, 	Avg.Score:  -230.850
# Ep.: 238 , timesteps:  87, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.8666, 	Avg.Score:  -226.710
# Ep.: 239 , timesteps:  91, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.5268, 	Avg.Score:  -225.380
# Ep.: 240 , timesteps:  77, noise_scale (Gt < best(Gt)): 2.0000, Gt -53.4119, 	Avg.Score:  -225.270
# Ep.: 241 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -229.470
# Ep.: 242 , timesteps:  75, noise_scale (Gt < best(Gt)): 2.0000, Gt -52.4660, 	Avg.Score:  -229.390
# Ep.: 243 , timesteps:  95, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.1216, 	Avg.Score:  -225.330
# Ep.: 244 , timesteps: 104, noise_scale (Gt < best(Gt)): 2.0000, Gt -64.4839, 	Avg.Score:  -221.360
# Ep.: 245 , timesteps:  95, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.1216, 	Avg.Score:  -217.300
# Ep.: 246 , timesteps: 104, noise_scale (Gt < best(Gt)): 2.0000, Gt -64.4839, 	Avg.Score:  -213.330
# Ep.: 247 , timesteps:  87, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.8666, 	Avg.Score:  -213.350
# Ep.: 248 , timesteps:  93, noise_scale (Gt < best(Gt)): 2.0000, Gt -60.3322, 	Avg.Score:  -209.270
# Ep.: 249 , timesteps: 100, noise_scale (Gt < best(Gt)): 2.0000, Gt -63.0270, 	Avg.Score:  -209.290
# Ep.: 250 , timesteps:  94, noise_scale (Gt < best(Gt)): 2.0000, Gt -60.7289, 	Avg.Score:  -209.100
# Ep.: 251 , timesteps: 186, noise_scale (Gt < best(Gt)): 2.0000, Gt -84.4220, 	Avg.Score:  -205.950
# Ep.: 252 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -205.950
# Ep.: 253 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -209.940
# Ep.: 254 , timesteps:  95, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.1216, 	Avg.Score:  -209.540
# Ep.: 255 , timesteps:  81, noise_scale (Gt < best(Gt)): 2.0000, Gt -55.2477, 	Avg.Score:  -205.340
# Ep.: 256 , timesteps:  86, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.4410, 	Avg.Score:  -201.190
# Ep.: 257 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -205.330
# Ep.: 258 , timesteps: 100, noise_scale (Gt < best(Gt)): 2.0000, Gt -63.0270, 	Avg.Score:  -205.470
# Ep.: 259 , timesteps:  96, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.5104, 	Avg.Score:  -205.580
# Ep.: 260 , timesteps: 116, noise_scale (Gt < best(Gt)): 2.0000, Gt -68.5191, 	Avg.Score:  -201.730
# Ep.: 261 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -205.790
# Ep.: 262 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -205.790
# Ep.: 263 , timesteps: 198, noise_scale (Gt < best(Gt)): 2.0000, Gt -86.1919, 	Avg.Score:  -206.740
# Ep.: 264 , timesteps: 109, noise_scale (Gt < best(Gt)): 2.0000, Gt -66.2246, 	Avg.Score:  -206.660
# Ep.: 265 , timesteps: 100, noise_scale (Gt < best(Gt)): 2.0000, Gt -63.0270, 	Avg.Score:  -202.650
# Ep.: 266 , timesteps: 129, noise_scale (Gt < best(Gt)): 2.0000, Gt -72.3748, 	Avg.Score:  -198.930
# Ep.: 267 , timesteps:  95, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.1216, 	Avg.Score:  -198.930
# Ep.: 268 , timesteps:  81, noise_scale (Gt < best(Gt)): 2.0000, Gt -55.2477, 	Avg.Score:  -198.730
# Ep.: 269 , timesteps: 137, noise_scale (Gt < best(Gt)): 2.0000, Gt -74.5090, 	Avg.Score:  -195.090
# Ep.: 270 , timesteps:  76, noise_scale (Gt < best(Gt)): 2.0000, Gt -52.9413, 	Avg.Score:  -194.870
# Ep.: 271 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -194.870
# Ep.: 272 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -198.800
# Ep.: 273 , timesteps: 121, noise_scale (Gt < best(Gt)): 2.0000, Gt -70.0620, 	Avg.Score:  -195.000
# Ep.: 274 , timesteps:  96, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.5104, 	Avg.Score:  -194.740
# Ep.: 275 , timesteps: 113, noise_scale (Gt < best(Gt)): 2.0000, Gt -67.5554, 	Avg.Score:  -195.200
# Ep.: 276 , timesteps:  91, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.5268, 	Avg.Score:  -195.220
# Ep.: 277 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -199.330
# Ep.: 278 , timesteps: 111, noise_scale (Gt < best(Gt)): 2.0000, Gt -66.8967, 	Avg.Score:  -195.430
# Ep.: 279 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -199.620
# Ep.: 280 , timesteps:  99, noise_scale (Gt < best(Gt)): 2.0000, Gt -62.6536, 	Avg.Score:  -195.600
# Ep.: 281 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -199.390
# Ep.: 282 , timesteps:  94, noise_scale (Gt < best(Gt)): 2.0000, Gt -60.7289, 	Avg.Score:  -198.560
# Ep.: 283 , timesteps: 124, noise_scale (Gt < best(Gt)): 2.0000, Gt -70.9512, 	Avg.Score:  -194.790
# Ep.: 284 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -194.790
# Ep.: 285 , timesteps:  81, noise_scale (Gt < best(Gt)): 2.0000, Gt -55.2477, 	Avg.Score:  -194.660
# Ep.: 286 , timesteps:  96, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.5104, 	Avg.Score:  -190.610
# Ep.: 287 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -190.610
# Ep.: 288 , timesteps:  94, noise_scale (Gt < best(Gt)): 2.0000, Gt -60.7289, 	Avg.Score:  -190.290
# Ep.: 289 , timesteps:  74, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.9859, 	Avg.Score:  -190.160
# Ep.: 290 , timesteps:  90, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.1180, 	Avg.Score:  -190.050
# Ep.: 291 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -194.260
# Ep.: 292 , timesteps: 150, noise_scale (Gt < best(Gt)): 2.0000, Gt -77.6311, 	Avg.Score:  -194.530
# Ep.: 293 , timesteps:  86, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.4410, 	Avg.Score:  -194.250
# Ep.: 294 , timesteps:  90, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.1180, 	Avg.Score:  -194.070
# Ep.: 295 , timesteps: 135, noise_scale (Gt < best(Gt)): 2.0000, Gt -73.9915, 	Avg.Score:  -190.410
# Ep.: 296 , timesteps:  87, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.8666, 	Avg.Score:  -190.410
# Ep.: 297 , timesteps:  80, noise_scale (Gt < best(Gt)): 2.0000, Gt -54.7956, 	Avg.Score:  -190.200
# Ep.: 298 , timesteps:  75, noise_scale (Gt < best(Gt)): 2.0000, Gt -52.4660, 	Avg.Score:  -189.970
# Ep.: 299 , timesteps: 118, noise_scale (Gt < best(Gt)): 2.0000, Gt -69.1456, 	Avg.Score:  -190.300
# Ep.: 300 , timesteps: 120, noise_scale (Gt < best(Gt)): 2.0000, Gt -69.7596, 	Avg.Score:  -190.200
# Ep.: 301 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -194.330
# Ep.: 302 , timesteps: 112, noise_scale (Gt < best(Gt)): 2.0000, Gt -67.2277, 	Avg.Score:  -194.710
# Ep.: 303 , timesteps:  96, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.5104, 	Avg.Score:  -194.760
# Ep.: 304 , timesteps:  90, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.1180, 	Avg.Score:  -194.620
# Ep.: 305 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -198.040
# Ep.: 306 , timesteps:  82, noise_scale (Gt < best(Gt)): 2.0000, Gt -55.6952, 	Avg.Score:  -197.100
# Ep.: 307 , timesteps:  72, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.0110, 	Avg.Score:  -192.810
# Ep.: 308 , timesteps:  88, noise_scale (Gt < best(Gt)): 2.0000, Gt -58.2879, 	Avg.Score:  -192.540
# Ep.: 309 , timesteps: 101, noise_scale (Gt < best(Gt)): 2.0000, Gt -63.3968, 	Avg.Score:  -192.370
# Ep.: 310 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -196.510
# Ep.: 311 , timesteps:  97, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.8953, 	Avg.Score:  -196.510
# Ep.: 312 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -200.780
# Ep.: 313 , timesteps:  88, noise_scale (Gt < best(Gt)): 2.0000, Gt -58.2879, 	Avg.Score:  -200.930
# Ep.: 314 , timesteps:  94, noise_scale (Gt < best(Gt)): 2.0000, Gt -60.7289, 	Avg.Score:  -200.960
# Ep.: 315 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -205.150
# Ep.: 316 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -208.320
# Ep.: 317 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -208.320
# Ep.: 318 , timesteps:  82, noise_scale (Gt < best(Gt)): 2.0000, Gt -55.6952, 	Avg.Score:  -208.210
# Ep.: 319 , timesteps: 111, noise_scale (Gt < best(Gt)): 2.0000, Gt -66.8967, 	Avg.Score:  -204.310
# Ep.: 320 , timesteps:  66, noise_scale (Gt >= best(Gt)): 1.0000, Gt -47.9659, 	Avg.Score:  -204.100
# Ep.: 321 , timesteps:  97, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.8953, 	Avg.Score:  -204.270
# Ep.: 322 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -208.470
# Ep.: 323 , timesteps: 114, noise_scale (Gt < best(Gt)): 2.0000, Gt -67.8799, 	Avg.Score:  -208.800
# Ep.: 324 , timesteps:  92, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.9315, 	Avg.Score:  -209.000
# Ep.: 325 , timesteps:  99, noise_scale (Gt < best(Gt)): 2.0000, Gt -62.6536, 	Avg.Score:  -204.980
# Ep.: 326 , timesteps: 117, noise_scale (Gt < best(Gt)): 2.0000, Gt -68.8339, 	Avg.Score:  -204.930
# Ep.: 327 , timesteps:  83, noise_scale (Gt < best(Gt)): 2.0000, Gt -56.1382, 	Avg.Score:  -200.750
# Ep.: 328 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -204.910
# Ep.: 329 , timesteps: 112, noise_scale (Gt < best(Gt)): 2.0000, Gt -67.2277, 	Avg.Score:  -201.020
# Ep.: 330 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -205.090
# Ep.: 331 , timesteps:  67, noise_scale (Gt < best(Gt)): 2.0000, Gt -48.4863, 	Avg.Score:  -200.750
# Ep.: 332 , timesteps: 114, noise_scale (Gt < best(Gt)): 2.0000, Gt -67.8799, 	Avg.Score:  -199.920
# Ep.: 333 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -204.140
# Ep.: 334 , timesteps: 126, noise_scale (Gt < best(Gt)): 2.0000, Gt -71.5292, 	Avg.Score:  -204.610
# Ep.: 335 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -204.610
# Ep.: 336 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -208.440
# Ep.: 337 , timesteps:  88, noise_scale (Gt < best(Gt)): 2.0000, Gt -58.2879, 	Avg.Score:  -207.270
# Ep.: 338 , timesteps:  89, noise_scale (Gt < best(Gt)): 2.0000, Gt -58.7050, 	Avg.Score:  -207.290
# Ep.: 339 , timesteps: 129, noise_scale (Gt < best(Gt)): 2.0000, Gt -72.3748, 	Avg.Score:  -207.670
# Ep.: 340 , timesteps:  98, noise_scale (Gt < best(Gt)): 2.0000, Gt -62.2763, 	Avg.Score:  -207.880
# Ep.: 341 , timesteps:  84, noise_scale (Gt < best(Gt)): 2.0000, Gt -56.5769, 	Avg.Score:  -203.710
# Ep.: 342 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -207.970
# Ep.: 343 , timesteps: 142, noise_scale (Gt < best(Gt)): 2.0000, Gt -75.7583, 	Avg.Score:  -208.440
# Ep.: 344 , timesteps: 108, noise_scale (Gt < best(Gt)): 2.0000, Gt -65.8834, 	Avg.Score:  -208.480
# Ep.: 345 , timesteps:  94, noise_scale (Gt < best(Gt)): 2.0000, Gt -60.7289, 	Avg.Score:  -208.470
# Ep.: 346 , timesteps: 197, noise_scale (Gt < best(Gt)): 2.0000, Gt -86.0524, 	Avg.Score:  -209.400
# Ep.: 347 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -213.540
# Ep.: 348 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -217.620
# Ep.: 349 , timesteps: 105, noise_scale (Gt < best(Gt)): 2.0000, Gt -64.8391, 	Avg.Score:  -217.670
# Ep.: 350 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -221.740
# Ep.: 351 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -224.890
# Ep.: 352 , timesteps: 123, noise_scale (Gt < best(Gt)): 2.0000, Gt -70.6577, 	Avg.Score:  -221.110
# Ep.: 353 , timesteps: 103, noise_scale (Gt < best(Gt)): 2.0000, Gt -64.1252, 	Avg.Score:  -217.130
# Ep.: 354 , timesteps: 108, noise_scale (Gt < best(Gt)): 2.0000, Gt -65.8834, 	Avg.Score:  -217.260
# Ep.: 355 , timesteps:  93, noise_scale (Gt < best(Gt)): 2.0000, Gt -60.3322, 	Avg.Score:  -217.380
# Ep.: 356 , timesteps: 108, noise_scale (Gt < best(Gt)): 2.0000, Gt -65.8834, 	Avg.Score:  -217.600
# Ep.: 357 , timesteps:  84, noise_scale (Gt < best(Gt)): 2.0000, Gt -56.5769, 	Avg.Score:  -213.430
# Ep.: 358 , timesteps: 177, noise_scale (Gt < best(Gt)): 2.0000, Gt -82.9473, 	Avg.Score:  -214.200
# Ep.: 359 , timesteps: 173, noise_scale (Gt < best(Gt)): 2.0000, Gt -82.2477, 	Avg.Score:  -214.970
# Ep.: 360 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -218.820
# Ep.: 361 , timesteps:  74, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.9859, 	Avg.Score:  -214.550
# Ep.: 362 , timesteps: 150, noise_scale (Gt < best(Gt)): 2.0000, Gt -77.6311, 	Avg.Score:  -211.040
# Ep.: 363 , timesteps:  98, noise_scale (Gt < best(Gt)): 2.0000, Gt -62.2763, 	Avg.Score:  -210.040
# Ep.: 364 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -213.960
# Ep.: 365 , timesteps: 455, noise_scale (Gt < best(Gt)): 2.0000, Gt -98.9568, 	Avg.Score:  -217.510
# Ep.: 366 , timesteps: 157, noise_scale (Gt < best(Gt)): 2.0000, Gt -79.1508, 	Avg.Score:  -217.790
# Ep.: 367 , timesteps: 109, noise_scale (Gt < best(Gt)): 2.0000, Gt -66.2246, 	Avg.Score:  -217.930
# Ep.: 368 , timesteps:  74, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.9859, 	Avg.Score:  -217.860
# Ep.: 369 , timesteps: 116, noise_scale (Gt < best(Gt)): 2.0000, Gt -68.5191, 	Avg.Score:  -217.650
# Ep.: 370 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -221.900
# Ep.: 371 , timesteps: 247, noise_scale (Gt < best(Gt)): 2.0000, Gt -91.5616, 	Avg.Score:  -219.360
# Ep.: 372 , timesteps:  97, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.8953, 	Avg.Score:  -215.320
# Ep.: 373 , timesteps:  84, noise_scale (Gt < best(Gt)): 2.0000, Gt -56.5769, 	Avg.Score:  -214.950
# Ep.: 374 , timesteps:  74, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.9859, 	Avg.Score:  -214.730
# Ep.: 375 , timesteps: 153, noise_scale (Gt < best(Gt)): 2.0000, Gt -78.2955, 	Avg.Score:  -215.130
# Ep.: 376 , timesteps: 106, noise_scale (Gt < best(Gt)): 2.0000, Gt -65.1907, 	Avg.Score:  -215.280
# Ep.: 377 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -215.280
# Ep.: 378 , timesteps:  81, noise_scale (Gt < best(Gt)): 2.0000, Gt -55.2477, 	Avg.Score:  -214.980
# Ep.: 379 , timesteps:  91, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.5268, 	Avg.Score:  -210.880
# Ep.: 380 , timesteps:  72, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.0110, 	Avg.Score:  -210.610
# Ep.: 381 , timesteps:  96, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.5104, 	Avg.Score:  -206.560
# Ep.: 382 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -210.630
# Ep.: 383 , timesteps: 108, noise_scale (Gt < best(Gt)): 2.0000, Gt -65.8834, 	Avg.Score:  -210.470
# Ep.: 384 , timesteps: 126, noise_scale (Gt < best(Gt)): 2.0000, Gt -71.5292, 	Avg.Score:  -206.720
# Ep.: 385 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -210.920
# Ep.: 386 , timesteps: 134, noise_scale (Gt < best(Gt)): 2.0000, Gt -73.7287, 	Avg.Score:  -211.300
# Ep.: 387 , timesteps:  91, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.5268, 	Avg.Score:  -207.200
# Ep.: 388 , timesteps:  98, noise_scale (Gt < best(Gt)): 2.0000, Gt -62.2763, 	Avg.Score:  -207.240
# Ep.: 389 , timesteps: 131, noise_scale (Gt < best(Gt)): 2.0000, Gt -72.9246, 	Avg.Score:  -207.810
# Ep.: 390 , timesteps: 118, noise_scale (Gt < best(Gt)): 2.0000, Gt -69.1456, 	Avg.Score:  -208.090
# Ep.: 391 , timesteps: 105, noise_scale (Gt < best(Gt)): 2.0000, Gt -64.8391, 	Avg.Score:  -204.130
# Ep.: 392 , timesteps: 105, noise_scale (Gt < best(Gt)): 2.0000, Gt -64.8391, 	Avg.Score:  -203.680
# Ep.: 393 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -207.830
# Ep.: 394 , timesteps: 320, noise_scale (Gt < best(Gt)): 2.0000, Gt -95.9484, 	Avg.Score:  -210.130
# Ep.: 395 , timesteps:  90, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.1180, 	Avg.Score:  -209.680
# Ep.: 396 , timesteps: 139, noise_scale (Gt < best(Gt)): 2.0000, Gt -75.0163, 	Avg.Score:  -210.200
# Ep.: 397 , timesteps:  89, noise_scale (Gt < best(Gt)): 2.0000, Gt -58.7050, 	Avg.Score:  -210.290
# Ep.: 398 , timesteps: 123, noise_scale (Gt < best(Gt)): 2.0000, Gt -70.6577, 	Avg.Score:  -210.770
# Ep.: 399 , timesteps:  87, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.8666, 	Avg.Score:  -210.460
# Ep.: 400 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -214.270
# Ep.: 401 , timesteps:  86, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.4410, 	Avg.Score:  -210.120
# Ep.: 402 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -214.010
# Ep.: 403 , timesteps:  81, noise_scale (Gt < best(Gt)): 2.0000, Gt -55.2477, 	Avg.Score:  -213.860
# Ep.: 404 , timesteps: 128, noise_scale (Gt < best(Gt)): 2.0000, Gt -72.0958, 	Avg.Score:  -214.240
# Ep.: 405 , timesteps:  86, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.4410, 	Avg.Score:  -210.090
# Ep.: 406 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -214.280
# Ep.: 407 , timesteps:  93, noise_scale (Gt < best(Gt)): 2.0000, Gt -60.3322, 	Avg.Score:  -214.490
# Ep.: 408 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -218.620
# Ep.: 409 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -222.620
# Ep.: 410 , timesteps: 191, noise_scale (Gt < best(Gt)): 2.0000, Gt -85.1855, 	Avg.Score:  -219.520
# Ep.: 411 , timesteps:  75, noise_scale (Gt < best(Gt)): 2.0000, Gt -52.4660, 	Avg.Score:  -219.300
# Ep.: 412 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -219.300
# Ep.: 413 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -223.430
# Ep.: 414 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -227.500
# Ep.: 415 , timesteps: 362, noise_scale (Gt < best(Gt)): 2.0000, Gt -97.3435, 	Avg.Score:  -226.110
# Ep.: 416 , timesteps: 114, noise_scale (Gt < best(Gt)): 2.0000, Gt -67.8799, 	Avg.Score:  -222.240
# Ep.: 417 , timesteps: 123, noise_scale (Gt < best(Gt)): 2.0000, Gt -70.6577, 	Avg.Score:  -218.460
# Ep.: 418 , timesteps:  65, noise_scale (Gt >= best(Gt)): 1.0000, Gt -47.4404, 	Avg.Score:  -218.290
# Ep.: 419 , timesteps: 154, noise_scale (Gt < best(Gt)): 2.0000, Gt -78.5126, 	Avg.Score:  -218.720
# Ep.: 420 , timesteps:  65, noise_scale (Gt >= best(Gt)): 1.0000, Gt -47.4404, 	Avg.Score:  -218.710
# Ep.: 421 , timesteps:  65, noise_scale (Gt >= best(Gt)): 0.5000, Gt -47.4404, 	Avg.Score:  -218.390
# Ep.: 422 , timesteps:  98, noise_scale (Gt < best(Gt)): 1.0000, Gt -62.2763, 	Avg.Score:  -214.360
# Ep.: 423 , timesteps:  76, noise_scale (Gt < best(Gt)): 2.0000, Gt -52.9413, 	Avg.Score:  -213.980
# Ep.: 424 , timesteps: 113, noise_scale (Gt < best(Gt)): 2.0000, Gt -67.5554, 	Avg.Score:  -214.190
# Ep.: 425 , timesteps:  90, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.1180, 	Avg.Score:  -214.100
# Ep.: 426 , timesteps:  83, noise_scale (Gt < best(Gt)): 2.0000, Gt -56.1382, 	Avg.Score:  -213.760
# Ep.: 427 , timesteps: 157, noise_scale (Gt < best(Gt)): 2.0000, Gt -79.1508, 	Avg.Score:  -214.500
# Ep.: 428 , timesteps:  81, noise_scale (Gt < best(Gt)): 2.0000, Gt -55.2477, 	Avg.Score:  -210.300
# Ep.: 429 , timesteps:  94, noise_scale (Gt < best(Gt)): 2.0000, Gt -60.7289, 	Avg.Score:  -210.120
# Ep.: 430 , timesteps: 107, noise_scale (Gt < best(Gt)): 2.0000, Gt -65.5388, 	Avg.Score:  -206.180
# Ep.: 431 , timesteps: 107, noise_scale (Gt < best(Gt)): 2.0000, Gt -65.5388, 	Avg.Score:  -206.580
# Ep.: 432 , timesteps:  98, noise_scale (Gt < best(Gt)): 2.0000, Gt -62.2763, 	Avg.Score:  -206.420
# Ep.: 433 , timesteps:  84, noise_scale (Gt < best(Gt)): 2.0000, Gt -56.5769, 	Avg.Score:  -202.250
# Ep.: 434 , timesteps: 175, noise_scale (Gt < best(Gt)): 2.0000, Gt -82.6010, 	Avg.Score:  -202.740
# Ep.: 435 , timesteps:  93, noise_scale (Gt < best(Gt)): 2.0000, Gt -60.3322, 	Avg.Score:  -198.660
# Ep.: 436 , timesteps: 174, noise_scale (Gt < best(Gt)): 2.0000, Gt -82.4253, 	Avg.Score:  -195.390
# Ep.: 437 , timesteps:  66, noise_scale (Gt < best(Gt)): 2.0000, Gt -47.9659, 	Avg.Score:  -195.170
# Ep.: 438 , timesteps:  74, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.9859, 	Avg.Score:  -195.020
# Ep.: 439 , timesteps:  96, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.5104, 	Avg.Score:  -194.690
# Ep.: 440 , timesteps:  98, noise_scale (Gt < best(Gt)): 2.0000, Gt -62.2763, 	Avg.Score:  -194.690
# Ep.: 441 , timesteps:  76, noise_scale (Gt < best(Gt)): 2.0000, Gt -52.9413, 	Avg.Score:  -194.610
# Ep.: 442 , timesteps:  74, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.9859, 	Avg.Score:  -190.340
# Ep.: 443 , timesteps:  92, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.9315, 	Avg.Score:  -189.840
# Ep.: 444 , timesteps:  86, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.4410, 	Avg.Score:  -189.620
# Ep.: 445 , timesteps:  86, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.4410, 	Avg.Score:  -189.540
# Ep.: 446 , timesteps:  73, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.5009, 	Avg.Score:  -188.300
# Ep.: 447 , timesteps:  65, noise_scale (Gt >= best(Gt)): 1.0000, Gt -47.4404, 	Avg.Score:  -183.940
# Ep.: 448 , timesteps:  73, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.5009, 	Avg.Score:  -179.660
# Ep.: 449 , timesteps: 121, noise_scale (Gt < best(Gt)): 2.0000, Gt -70.0620, 	Avg.Score:  -179.820
# Ep.: 450 , timesteps:  65, noise_scale (Gt >= best(Gt)): 1.0000, Gt -47.4404, 	Avg.Score:  -175.460
# Ep.: 451 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -175.460
# Ep.: 452 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -179.240
# Ep.: 453 , timesteps:  73, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.5009, 	Avg.Score:  -178.940
# Ep.: 454 , timesteps:  90, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.1180, 	Avg.Score:  -178.760
# Ep.: 455 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -182.840
# Ep.: 456 , timesteps:  65, noise_scale (Gt >= best(Gt)): 1.0000, Gt -47.4404, 	Avg.Score:  -182.410
# Ep.: 457 , timesteps:  65, noise_scale (Gt >= best(Gt)): 0.5000, Gt -47.4404, 	Avg.Score:  -182.220
# Ep.: 458 , timesteps:  96, noise_scale (Gt < best(Gt)): 1.0000, Gt -61.5104, 	Avg.Score:  -181.410
# Ep.: 459 , timesteps:  72, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.0110, 	Avg.Score:  -180.400
# Ep.: 460 , timesteps:  66, noise_scale (Gt < best(Gt)): 2.0000, Gt -47.9659, 	Avg.Score:  -176.050
# Ep.: 461 , timesteps:  81, noise_scale (Gt < best(Gt)): 2.0000, Gt -55.2477, 	Avg.Score:  -176.120
# Ep.: 462 , timesteps: 112, noise_scale (Gt < best(Gt)): 2.0000, Gt -67.2277, 	Avg.Score:  -175.740
# Ep.: 463 , timesteps: 122, noise_scale (Gt < best(Gt)): 2.0000, Gt -70.3613, 	Avg.Score:  -175.980
# Ep.: 464 , timesteps:  89, noise_scale (Gt < best(Gt)): 2.0000, Gt -58.7050, 	Avg.Score:  -171.860
# Ep.: 465 , timesteps:  75, noise_scale (Gt < best(Gt)): 2.0000, Gt -52.4660, 	Avg.Score:  -168.060
# Ep.: 466 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -171.500
# Ep.: 467 , timesteps:  79, noise_scale (Gt < best(Gt)): 2.0000, Gt -54.3390, 	Avg.Score:  -171.200
# Ep.: 468 , timesteps:  75, noise_scale (Gt < best(Gt)): 2.0000, Gt -52.4660, 	Avg.Score:  -171.210
# Ep.: 469 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -175.060
# Ep.: 470 , timesteps:  90, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.1180, 	Avg.Score:  -170.950
# Ep.: 471 , timesteps: 101, noise_scale (Gt < best(Gt)): 2.0000, Gt -63.3968, 	Avg.Score:  -169.490
# Ep.: 472 , timesteps:  97, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.8953, 	Avg.Score:  -169.490
# Ep.: 473 , timesteps:  65, noise_scale (Gt >= best(Gt)): 1.0000, Gt -47.4404, 	Avg.Score:  -169.300
# Ep.: 474 , timesteps:  65, noise_scale (Gt >= best(Gt)): 0.5000, Gt -47.4404, 	Avg.Score:  -169.210
# Ep.: 475 , timesteps:  90, noise_scale (Gt < best(Gt)): 1.0000, Gt -59.1180, 	Avg.Score:  -168.580
# Ep.: 476 , timesteps:  73, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.5009, 	Avg.Score:  -168.250
# Ep.: 477 , timesteps:  72, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.0110, 	Avg.Score:  -163.960
# Ep.: 478 , timesteps: 102, noise_scale (Gt < best(Gt)): 2.0000, Gt -63.7628, 	Avg.Score:  -164.170
# Ep.: 479 , timesteps:  65, noise_scale (Gt >= best(Gt)): 1.0000, Gt -47.4404, 	Avg.Score:  -163.910
# Ep.: 480 , timesteps: 176, noise_scale (Gt < best(Gt)): 2.0000, Gt -82.7750, 	Avg.Score:  -164.950
# Ep.: 481 , timesteps:  73, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.5009, 	Avg.Score:  -164.720
# Ep.: 482 , timesteps: 107, noise_scale (Gt < best(Gt)): 2.0000, Gt -65.5388, 	Avg.Score:  -160.780
# Ep.: 483 , timesteps:  90, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.1180, 	Avg.Score:  -160.600
# ...
# Ep.: 692 , timesteps: 103, noise_scale (Gt < best(Gt)): 2.0000, Gt -64.1252, 	Avg.Score:  -167.560
# Ep.: 693 , timesteps:  74, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.9859, 	Avg.Score:  -167.410
# Ep.: 694 , timesteps:  75, noise_scale (Gt < best(Gt)): 2.0000, Gt -52.4660, 	Avg.Score:  -167.380
# Ep.: 695 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -171.470
# Ep.: 696 , timesteps:  79, noise_scale (Gt < best(Gt)): 2.0000, Gt -54.3390, 	Avg.Score:  -171.540
# Ep.: 697 , timesteps:  76, noise_scale (Gt < best(Gt)): 2.0000, Gt -52.9413, 	Avg.Score:  -171.560
# Ep.: 698 , timesteps:  95, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.1216, 	Avg.Score:  -171.660
# Ep.: 699 , timesteps: 105, noise_scale (Gt < best(Gt)): 2.0000, Gt -64.8391, 	Avg.Score:  -167.700
# Ep.: 700 , timesteps:  78, noise_scale (Gt < best(Gt)): 2.0000, Gt -53.8778, 	Avg.Score:  -167.690
# Ep.: 701 , timesteps:  85, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.0111, 	Avg.Score:  -167.810
# Ep.: 702 , timesteps:  77, noise_scale (Gt < best(Gt)): 2.0000, Gt -53.4119, 	Avg.Score:  -167.800
# Ep.: 703 , timesteps:  91, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.5268, 	Avg.Score:  -166.800
# Ep.: 704 , timesteps:  99, noise_scale (Gt < best(Gt)): 2.0000, Gt -62.6536, 	Avg.Score:  -167.070
# Ep.: 705 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -171.340
# Ep.: 706 , timesteps:  97, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.8953, 	Avg.Score:  -171.470
# Ep.: 707 , timesteps:  75, noise_scale (Gt < best(Gt)): 2.0000, Gt -52.4660, 	Avg.Score:  -167.210
# Ep.: 708 , timesteps:  73, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.5009, 	Avg.Score:  -167.180
# Ep.: 709 , timesteps:  88, noise_scale (Gt < best(Gt)): 2.0000, Gt -58.2879, 	Avg.Score:  -167.220
# Ep.: 710 , timesteps:  80, noise_scale (Gt < best(Gt)): 2.0000, Gt -54.7956, 	Avg.Score:  -166.480
# Ep.: 711 , timesteps:  97, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.8953, 	Avg.Score:  -166.660
# Ep.: 712 , timesteps: 101, noise_scale (Gt < best(Gt)): 2.0000, Gt -63.3968, 	Avg.Score:  -162.660
# Ep.: 713 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -162.660
# Ep.: 714 , timesteps:  89, noise_scale (Gt < best(Gt)): 2.0000, Gt -58.7050, 	Avg.Score:  -162.650
# Ep.: 715 , timesteps:  72, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.0110, 	Avg.Score:  -161.090
# Ep.: 716 , timesteps: 102, noise_scale (Gt < best(Gt)): 2.0000, Gt -63.7628, 	Avg.Score:  -161.370
# Ep.: 717 , timesteps:  81, noise_scale (Gt < best(Gt)): 2.0000, Gt -55.2477, 	Avg.Score:  -161.420
# Ep.: 718 , timesteps:  65, noise_scale (Gt >= best(Gt)): 1.0000, Gt -47.4404, 	Avg.Score:  -161.150
# Ep.: 719 , timesteps:  84, noise_scale (Gt < best(Gt)): 2.0000, Gt -56.5769, 	Avg.Score:  -161.090
# Ep.: 720 , timesteps:  80, noise_scale (Gt < best(Gt)): 2.0000, Gt -54.7956, 	Avg.Score:  -156.880
# Ep.: 721 , timesteps:  77, noise_scale (Gt < best(Gt)): 2.0000, Gt -53.4119, 	Avg.Score:  -156.910
# Ep.: 722 , timesteps:  74, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.9859, 	Avg.Score:  -156.570
# Ep.: 723 , timesteps: 249, noise_scale (Gt < best(Gt)): 2.0000, Gt -91.7296, 	Avg.Score:  -154.050
# Ep.: 724 , timesteps:  96, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.5104, 	Avg.Score:  -154.210
# Ep.: 725 , timesteps: 124, noise_scale (Gt < best(Gt)): 2.0000, Gt -70.9512, 	Avg.Score:  -154.410
# Ep.: 726 , timesteps:  95, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.1216, 	Avg.Score:  -154.520
# Ep.: 727 , timesteps:  96, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.5104, 	Avg.Score:  -154.700
# Ep.: 728 , timesteps:  77, noise_scale (Gt < best(Gt)): 2.0000, Gt -53.4119, 	Avg.Score:  -154.670
# Ep.: 729 , timesteps:  90, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.1180, 	Avg.Score:  -154.700
# Ep.: 730 , timesteps:  75, noise_scale (Gt < best(Gt)): 2.0000, Gt -52.4660, 	Avg.Score:  -154.440
# Ep.: 731 , timesteps:  96, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.5104, 	Avg.Score:  -154.440
# Ep.: 732 , timesteps: 104, noise_scale (Gt < best(Gt)): 2.0000, Gt -64.4839, 	Avg.Score:  -154.760
# Ep.: 733 , timesteps:  77, noise_scale (Gt < best(Gt)): 2.0000, Gt -53.4119, 	Avg.Score:  -154.530
# Ep.: 734 , timesteps:  65, noise_scale (Gt >= best(Gt)): 1.0000, Gt -47.4404, 	Avg.Score:  -154.280
# Ep.: 735 , timesteps:  91, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.5268, 	Avg.Score:  -150.180
# Ep.: 736 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -154.020
# Ep.: 737 , timesteps:  75, noise_scale (Gt < best(Gt)): 2.0000, Gt -52.4660, 	Avg.Score:  -154.030
# Ep.: 738 , timesteps:  93, noise_scale (Gt < best(Gt)): 2.0000, Gt -60.3322, 	Avg.Score:  -154.200
# Ep.: 739 , timesteps: 100, noise_scale (Gt < best(Gt)): 2.0000, Gt -63.0270, 	Avg.Score:  -150.190
# Ep.: 740 , timesteps:  84, noise_scale (Gt < best(Gt)): 2.0000, Gt -56.5769, 	Avg.Score:  -150.070
# Ep.: 741 , timesteps:  90, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.1180, 	Avg.Score:  -150.240
# Ep.: 742 , timesteps:  84, noise_scale (Gt < best(Gt)): 2.0000, Gt -56.5769, 	Avg.Score:  -150.360
# Ep.: 743 , timesteps:  85, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.0111, 	Avg.Score:  -146.200
# Ep.: 744 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -150.550
# Ep.: 745 , timesteps:  80, noise_scale (Gt < best(Gt)): 2.0000, Gt -54.7956, 	Avg.Score:  -150.300
# Ep.: 746 , timesteps:  99, noise_scale (Gt < best(Gt)): 2.0000, Gt -62.6536, 	Avg.Score:  -150.030
# Ep.: 747 , timesteps:  95, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.1216, 	Avg.Score:  -149.960
# Ep.: 748 , timesteps: 108, noise_scale (Gt < best(Gt)): 2.0000, Gt -65.8834, 	Avg.Score:  -150.190
# Ep.: 749 , timesteps:  75, noise_scale (Gt < best(Gt)): 2.0000, Gt -52.4660, 	Avg.Score:  -150.100
# Ep.: 750 , timesteps:  98, noise_scale (Gt < best(Gt)): 2.0000, Gt -62.2763, 	Avg.Score:  -150.090
# Ep.: 751 , timesteps: 230, noise_scale (Gt < best(Gt)): 2.0000, Gt -89.9894, 	Avg.Score:  -151.140
# Ep.: 752 , timesteps:  89, noise_scale (Gt < best(Gt)): 2.0000, Gt -58.7050, 	Avg.Score:  -151.190
# Ep.: 753 , timesteps:  86, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.4410, 	Avg.Score:  -151.150
# Ep.: 754 , timesteps:  85, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.0111, 	Avg.Score:  -146.990
# Ep.: 755 , timesteps:  84, noise_scale (Gt < best(Gt)): 2.0000, Gt -56.5769, 	Avg.Score:  -147.100
# Ep.: 756 , timesteps:  90, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.1180, 	Avg.Score:  -142.990
# Ep.: 757 , timesteps:  82, noise_scale (Gt < best(Gt)): 2.0000, Gt -55.6952, 	Avg.Score:  -142.880
# Ep.: 758 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -146.930
# Ep.: 759 , timesteps:  93, noise_scale (Gt < best(Gt)): 2.0000, Gt -60.3322, 	Avg.Score:  -142.850
# Ep.: 760 , timesteps:  84, noise_scale (Gt < best(Gt)): 2.0000, Gt -56.5769, 	Avg.Score:  -138.680
# Ep.: 761 , timesteps:  96, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.5104, 	Avg.Score:  -138.920
# Ep.: 762 , timesteps:  89, noise_scale (Gt < best(Gt)): 2.0000, Gt -58.7050, 	Avg.Score:  -134.800
# Ep.: 763 , timesteps:  65, noise_scale (Gt >= best(Gt)): 1.0000, Gt -47.4404, 	Avg.Score:  -134.710
# Ep.: 764 , timesteps: 101, noise_scale (Gt < best(Gt)): 2.0000, Gt -63.3968, 	Avg.Score:  -134.880
# Ep.: 765 , timesteps: 125, noise_scale (Gt < best(Gt)): 2.0000, Gt -71.2416, 	Avg.Score:  -131.120
# Ep.: 766 , timesteps: 114, noise_scale (Gt < best(Gt)): 2.0000, Gt -67.8799, 	Avg.Score:  -127.250
# Ep.: 767 , timesteps: 108, noise_scale (Gt < best(Gt)): 2.0000, Gt -65.8834, 	Avg.Score:  -127.430
# Ep.: 768 , timesteps: 111, noise_scale (Gt < best(Gt)): 2.0000, Gt -66.8967, 	Avg.Score:  -127.810
# Ep.: 769 , timesteps: 111, noise_scale (Gt < best(Gt)): 2.0000, Gt -66.8967, 	Avg.Score:  -128.010
# Ep.: 770 , timesteps: 183, noise_scale (Gt < best(Gt)): 2.0000, Gt -83.9452, 	Avg.Score:  -128.810
# Ep.: 771 , timesteps:  85, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.0111, 	Avg.Score:  -128.830
# Ep.: 772 , timesteps: 127, noise_scale (Gt < best(Gt)): 2.0000, Gt -71.8139, 	Avg.Score:  -128.840
# Ep.: 773 , timesteps:  77, noise_scale (Gt < best(Gt)): 2.0000, Gt -53.4119, 	Avg.Score:  -128.770
# Ep.: 774 , timesteps:  89, noise_scale (Gt < best(Gt)): 2.0000, Gt -58.7050, 	Avg.Score:  -128.760
# Ep.: 775 , timesteps:  74, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.9859, 	Avg.Score:  -124.490
# Ep.: 776 , timesteps:  88, noise_scale (Gt < best(Gt)): 2.0000, Gt -58.2879, 	Avg.Score:  -124.520
# Ep.: 777 , timesteps: 105, noise_scale (Gt < best(Gt)): 2.0000, Gt -64.8391, 	Avg.Score:  -124.400
# Ep.: 778 , timesteps: 119, noise_scale (Gt < best(Gt)): 2.0000, Gt -69.4541, 	Avg.Score:  -120.580
# Ep.: 779 , timesteps: 105, noise_scale (Gt < best(Gt)): 2.0000, Gt -64.8391, 	Avg.Score:  -116.620
# Ep.: 780 , timesteps: 130, noise_scale (Gt < best(Gt)): 2.0000, Gt -72.6511, 	Avg.Score:  -117.140
# Ep.: 781 , timesteps: 113, noise_scale (Gt < best(Gt)): 2.0000, Gt -67.5554, 	Avg.Score:  -117.330
# Ep.: 782 , timesteps: 105, noise_scale (Gt < best(Gt)): 2.0000, Gt -64.8391, 	Avg.Score:  -117.660
# Ep.: 783 , timesteps: 142, noise_scale (Gt < best(Gt)): 2.0000, Gt -75.7583, 	Avg.Score:  -118.340
# Ep.: 784 , timesteps: 155, noise_scale (Gt < best(Gt)): 2.0000, Gt -78.7274, 	Avg.Score:  -118.920
# Ep.: 785 , timesteps: 500, noise_scale (Gt < best(Gt)): 2.0000, Gt -99.3430, 	Avg.Score:  -123.140
# Ep.: 786 , timesteps: 135, noise_scale (Gt < best(Gt)): 2.0000, Gt -73.9915, 	Avg.Score:  -123.530
# Ep.: 787 , timesteps:  83, noise_scale (Gt < best(Gt)): 2.0000, Gt -56.1382, 	Avg.Score:  -123.600
# Ep.: 788 , timesteps:  84, noise_scale (Gt < best(Gt)): 2.0000, Gt -56.5769, 	Avg.Score:  -123.720
# Ep.: 789 , timesteps: 112, noise_scale (Gt < best(Gt)): 2.0000, Gt -67.2277, 	Avg.Score:  -124.060
# Ep.: 790 , timesteps:  90, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.1180, 	Avg.Score:  -124.230
# Ep.: 791 , timesteps:  78, noise_scale (Gt < best(Gt)): 2.0000, Gt -53.8778, 	Avg.Score:  -124.020
# Ep.: 792 , timesteps:  65, noise_scale (Gt >= best(Gt)): 1.0000, Gt -47.4404, 	Avg.Score:  -123.640
# Ep.: 793 , timesteps:  73, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.5009, 	Avg.Score:  -123.630
# Ep.: 794 , timesteps:  97, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.8953, 	Avg.Score:  -123.850
# Ep.: 795 , timesteps: 140, noise_scale (Gt < best(Gt)): 2.0000, Gt -75.2661, 	Avg.Score:  -120.240
# Ep.: 796 , timesteps:  83, noise_scale (Gt < best(Gt)): 2.0000, Gt -56.1382, 	Avg.Score:  -120.280
# Ep.: 797 , timesteps:  96, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.5104, 	Avg.Score:  -120.480
# Ep.: 798 , timesteps:  76, noise_scale (Gt < best(Gt)): 2.0000, Gt -52.9413, 	Avg.Score:  -120.290
# Ep.: 799 , timesteps:  79, noise_scale (Gt < best(Gt)): 2.0000, Gt -54.3390, 	Avg.Score:  -120.030
# Ep.: 800 , timesteps: 135, noise_scale (Gt < best(Gt)): 2.0000, Gt -73.9915, 	Avg.Score:  -120.600
# Ep.: 801 , timesteps:  78, noise_scale (Gt < best(Gt)): 2.0000, Gt -53.8778, 	Avg.Score:  -120.530
# Ep.: 802 , timesteps:  75, noise_scale (Gt < best(Gt)): 2.0000, Gt -52.4660, 	Avg.Score:  -120.510
# Ep.: 803 , timesteps:  83, noise_scale (Gt < best(Gt)): 2.0000, Gt -56.1382, 	Avg.Score:  -120.430
# Ep.: 804 , timesteps:  73, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.5009, 	Avg.Score:  -120.170
# Ep.: 805 , timesteps:  80, noise_scale (Gt < best(Gt)): 2.0000, Gt -54.7956, 	Avg.Score:  -115.960
# Ep.: 806 , timesteps:  93, noise_scale (Gt < best(Gt)): 2.0000, Gt -60.3322, 	Avg.Score:  -115.920
# Ep.: 807 , timesteps:  97, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.8953, 	Avg.Score:  -116.140
# Ep.: 808 , timesteps:  95, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.1216, 	Avg.Score:  -116.360
# Ep.: 809 , timesteps:  72, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.0110, 	Avg.Score:  -116.200
# Ep.: 810 , timesteps:  73, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.5009, 	Avg.Score:  -116.130
# Ep.: 811 , timesteps:  80, noise_scale (Gt < best(Gt)): 2.0000, Gt -54.7956, 	Avg.Score:  -115.960
# Ep.: 812 , timesteps:  89, noise_scale (Gt < best(Gt)): 2.0000, Gt -58.7050, 	Avg.Score:  -115.840
# Ep.: 813 , timesteps: 102, noise_scale (Gt < best(Gt)): 2.0000, Gt -63.7628, 	Avg.Score:  -111.850
# Ep.: 814 , timesteps:  89, noise_scale (Gt < best(Gt)): 2.0000, Gt -58.7050, 	Avg.Score:  -111.850
# Ep.: 815 , timesteps:  73, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.5009, 	Avg.Score:  -111.860
# Ep.: 816 , timesteps:  90, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.1180, 	Avg.Score:  -111.740
# Ep.: 817 , timesteps:  72, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.0110, 	Avg.Score:  -111.650
# Ep.: 818 , timesteps: 102, noise_scale (Gt < best(Gt)): 2.0000, Gt -63.7628, 	Avg.Score:  -112.020
# Ep.: 819 , timesteps:  71, noise_scale (Gt < best(Gt)): 2.0000, Gt -50.5161, 	Avg.Score:  -111.890
# Ep.: 820 , timesteps: 136, noise_scale (Gt < best(Gt)): 2.0000, Gt -74.2515, 	Avg.Score:  -112.450
# Ep.: 821 , timesteps:  72, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.0110, 	Avg.Score:  -112.400
# Ep.: 822 , timesteps:  82, noise_scale (Gt < best(Gt)): 2.0000, Gt -55.6952, 	Avg.Score:  -112.480
# Ep.: 823 , timesteps:  72, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.0110, 	Avg.Score:  -110.710
# Ep.: 824 , timesteps:  84, noise_scale (Gt < best(Gt)): 2.0000, Gt -56.5769, 	Avg.Score:  -110.590
# Ep.: 825 , timesteps:  81, noise_scale (Gt < best(Gt)): 2.0000, Gt -55.2477, 	Avg.Score:  -110.160
# Ep.: 826 , timesteps:  95, noise_scale (Gt < best(Gt)): 2.0000, Gt -61.1216, 	Avg.Score:  -110.160
# Ep.: 827 , timesteps:  65, noise_scale (Gt >= best(Gt)): 1.0000, Gt -47.4404, 	Avg.Score:  -109.850
# Ep.: 828 , timesteps:  73, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.5009, 	Avg.Score:  -109.810
# Ep.: 829 , timesteps:  89, noise_scale (Gt < best(Gt)): 2.0000, Gt -58.7050, 	Avg.Score:  -109.800
# Ep.: 830 , timesteps:  90, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.1180, 	Avg.Score:  -109.950
# Ep.: 831 , timesteps:  90, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.1180, 	Avg.Score:  -109.890
# Ep.: 832 , timesteps:  81, noise_scale (Gt < best(Gt)): 2.0000, Gt -55.2477, 	Avg.Score:  -109.660
# Ep.: 833 , timesteps:  81, noise_scale (Gt < best(Gt)): 2.0000, Gt -55.2477, 	Avg.Score:  -109.700
# Ep.: 834 , timesteps:  92, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.9315, 	Avg.Score:  -109.970
# Ep.: 835 , timesteps:  90, noise_scale (Gt < best(Gt)): 2.0000, Gt -59.1180, 	Avg.Score:  -109.960
# Ep.: 836 , timesteps:  75, noise_scale (Gt < best(Gt)): 2.0000, Gt -52.4660, 	Avg.Score:  -105.700
# Ep.: 837 , timesteps:  81, noise_scale (Gt < best(Gt)): 2.0000, Gt -55.2477, 	Avg.Score:  -105.760
# Ep.: 838 , timesteps: 102, noise_scale (Gt < best(Gt)): 2.0000, Gt -63.7628, 	Avg.Score:  -105.850
# Ep.: 839 , timesteps:  65, noise_scale (Gt >= best(Gt)): 1.0000, Gt -47.4404, 	Avg.Score:  -105.500
# Ep.: 840 , timesteps:  73, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.5009, 	Avg.Score:  -105.390
# Ep.: 841 , timesteps: 105, noise_scale (Gt < best(Gt)): 2.0000, Gt -64.8391, 	Avg.Score:  -105.540
# Ep.: 842 , timesteps:  87, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.8666, 	Avg.Score:  -105.570
# Ep.: 843 , timesteps:  78, noise_scale (Gt < best(Gt)): 2.0000, Gt -53.8778, 	Avg.Score:  -105.500
# Ep.: 844 , timesteps:  82, noise_scale (Gt < best(Gt)): 2.0000, Gt -55.6952, 	Avg.Score:  -101.310
# Ep.: 845 , timesteps:  87, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.8666, 	Avg.Score:  -101.380
# Ep.: 846 , timesteps: 120, noise_scale (Gt < best(Gt)): 2.0000, Gt -69.7596, 	Avg.Score:  -101.590
# Ep.: 847 , timesteps:  65, noise_scale (Gt >= best(Gt)): 1.0000, Gt -47.4404, 	Avg.Score:  -101.290
# Ep.: 848 , timesteps:  73, noise_scale (Gt < best(Gt)): 2.0000, Gt -51.5009, 	Avg.Score:  -100.940
# Ep.: 849 , timesteps:  84, noise_scale (Gt < best(Gt)): 2.0000, Gt -56.5769, 	Avg.Score:  -101.030
# Ep.: 850 , timesteps:  85, noise_scale (Gt < best(Gt)): 2.0000, Gt -57.0111, 	Avg.Score:  -100.900
# Ep.: 851 , timesteps:  78, noise_scale (Gt < best(Gt)): 2.0000, Gt -53.8778, 	Avg.Score:  -99.380
# Environment solved in 851 episodes!	Average Score: -99.38
